# %% [markdown]
# <a href="https://colab.research.google.com/github/RaviKcse08/datascience_projs/blob/main/TF_Celsius2Fahrenheit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf

# %%
import logging
logger = tf.get_logger()
logger.setLevel(logging.ERROR)

# %%
import numpy as np


##Create 2 lists
celsius_q    = np.array([-40, -10,  0,  8, 15, 22,  38],  dtype=float)
fahrenheit_a = np.array([-40,  14, 32, 46, 59, 72, 100],  dtype=float)

for i,c in enumerate(celsius_q):
  print("{} degrees Celsius = {} degrees Fahrenheit".format(c, fahrenheit_a[i]))
# Out:
# -40.0 degrees Celsius = -40.0 degrees Fahrenheit
# -10.0 degrees Celsius = 14.0 degrees Fahrenheit
# 0.0 degrees Celsius = 32.0 degrees Fahrenheit
# 8.0 degrees Celsius = 46.0 degrees Fahrenheit
# 15.0 degrees Celsius = 59.0 degrees Fahrenheit
# 22.0 degrees Celsius = 72.0 degrees Fahrenheit
# 38.0 degrees Celsius = 100.0 degrees Fahrenheit

# %%
#L1 = tf.keras.layers.Dense(units=1, input_shape=[1])
L1 = tf.keras.layers.Dense(units=1,input_shape=[1])
model = tf.keras.Sequential([L1])

# %%
model.compile(loss=tf.keras.losses.MeanSquaredError(),optimizer=tf.keras.optimizers.RMSprop(learning_rate=0.001))
#model.compile(loss='mean_squared_error',optimizer=tf.keras.optimizers.Adam(0.1))

# %%
t_model = model.fit(celsius_q, fahrenheit_a, epochs=500, verbose=False)
print("Model is trained")
# Out:
# Model is trained

# %%
import matplotlib.pyplot as plt
plt.xlabel('Epoch Number')
plt.ylabel("Loss Magnitude")

plt.plot(t_model.history['loss'])

# %%
print(model.predict([100]))
# Out:
# 1/1 [==============================] - 0s 101ms/step
# [[110.21049]]

# %%
#print weights
print(L1.get_weights())
# Out:
# [array([[1.0970204]], dtype=float32), array([0.50844646], dtype=float32)]

# %%
#complex with more dense layer
import tensorflow as tf
#l0 = tf.keras.layers.Dense(units=4, input_shape=[1])
#l1 = tf.keras.layers.Dense(units=4)
#l2 = tf.keras.layers.Dense(units=1)
model = tf.keras.Sequential()
model.add(tf.keras.Input(shape=(1,)))
model.add(tf.keras.layers.Dense(4))
model.add(tf.keras.layers.Dense(4))
model.add(tf.keras.layers.Dense(1))
model.compile(loss=tf.keras.losses.MeanSquaredError(), optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),metrics=['accuracy'])

# %%
ht = model.fit(celsius_q, fahrenheit_a, epochs=300, verbose=False)
print("Finished training the model")
# Out:
# Finished training the model

# %%
import matplotlib.pyplot as plt
plt.xlabel("Epochs")
plt.ylabel("Loss magnu")
plt.plot(ht.history['loss'])
print(model.predict([100]))
# Out:
# 1/1 [==============================] - 0s 85ms/step
# [[211.7475]]
